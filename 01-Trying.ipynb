# %% [markdown]
# # Try it First

# %% [markdown]
# * Provides a temporary install with a number of pre-installed packages.
# * Your notebooks are deleted immediately you leave.
# * Great for fooling around and testing things out.
#
# ## https://try.jupyter.org/
#
#
# 1. Open https://try.jupyter.org/
# 1. It builds a new environment and puts some files in it; with a collection of different languages.
# 1. Check out "featured -> pandas cookbook -> cookbook" for a collection of interactive tutorial/demos
# 1. Click "New -> Python 2" to create a new notebook
# 1. Paste the code below into it and hit Shift-Enter

# %% [markdown]
# ## Plot a straight line and label the y axis

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# Easy, wasn't it!

# %% [markdown]
# ## Plot more charts

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))

# generate some random test data
all_data = [np.random.normal(0, std, 100) for std in range(6, 10)]

# plot violin plot
axes[0].violinplot(all_data,
                   showmeans=False,
                   showmedians=True)
axes[0].set_title('violin plot')

# plot box plot
axes[1].boxplot(all_data)
axes[1].set_title('box plot')

# adding horizontal grid lines
for ax in axes:
    ax.yaxis.grid(True)
    ax.set_xticks([y+1 for y in range(len(all_data))])
    ax.set_xlabel('xlabel')
    ax.set_ylabel('ylabel')

# add x-tick labels
plt.setp(axes, xticks=[y+1 for y in range(len(all_data))],
         xticklabels=['x1', 'x2', 'x3', 'x4'])
plt.show()

# %% [markdown]
# There's a wealth of examples of plotting with matplotlib at
# https://matplotlib.org/examples/index.html

# %% [markdown]
# # But Why?
#
# So you can build, and publish, your own case studies to the world.
#
# # But How?
#
# By creating a notebook which:
#
# 1. imports your data
# 2. charts your data
# 3. explains your data
#
# Then saving the notebook and handing it to IT for publication to MQDashboard.
#
# The idea is that it will:
#
# * get everyone's work published online quickly
# * exactly as you prepared it
# * in a form that others can play with
# * without costing IT lots of time and money
